# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Flatten images

x_train = x_train.reshape(x_train.shape[0], 784)
x_test = x_test.reshape(x_test.shape[0], 784)

# Normalize pixel values

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def relu(z):
    return np.maximum(0, z)

# %%
def tanh(z):
    return np.tanh(z)

# %%
def softmax(z):

    exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))

    return exp_z / np.sum(exp_z, axis=1, keepdims=True)

# %%
hidden_layers = [128, 64]

# %%
class FeedForwardNeuralNetwork:

    def __init__(self, input_size, hidden_layers, output_size):

        self.layers = [input_size] + hidden_layers + [output_size]

        self.weights = []
        self.biases = []

        # Initialize weights and biases

        for i in range(len(self.layers) - 1):

            weight = np.random.randn(
                self.layers[i],
                self.layers[i + 1]
            ) * np.sqrt(1 / self.layers[i])

            bias = np.zeros((1, self.layers[i + 1]))

            self.weights.append(weight)
            self.biases.append(bias)
    def forward(self, X):

        activations = [X]

        A = X

        # Hidden layers

        for i in range(len(self.weights) - 1):

            Z = np.dot(A, self.weights[i]) + self.biases[i]

            A = relu(Z)

            activations.append(A)

        # Output layer

        Z = np.dot(A, self.weights[-1]) + self.biases[-1]

        output = softmax(Z)

        activations.append(output)

        return activations

# %%
layers = [784, 128, 64, 10]

# %%
model = FeedForwardNeuralNetwork(
    input_size=784,
    hidden_layers=[128, 64],
    output_size=10
)

# %%
sample_input = x_train[:5]

outputs = model.forward(sample_input)

print(outputs[-1])
# Out:
# [[0.13148797 0.10352663 0.10045571 0.07816432 0.07838445 0.04975124
#   0.12374898 0.12433148 0.10758302 0.10256621]
#  [0.09620049 0.11659428 0.1331726  0.08884131 0.10504372 0.0434049
#   0.10248937 0.11035778 0.08894349 0.11495205]
#  [0.0994486  0.11528484 0.11507132 0.107614   0.09891901 0.07907644
#   0.10354728 0.09663514 0.0943907  0.09001267]
#  [0.09580592 0.10892133 0.11260355 0.09687929 0.11187619 0.0731389
#   0.10597765 0.09829708 0.10492838 0.0915717 ]
#  [0.10233629 0.13822211 0.11125155 0.10579929 0.13273081 0.06436715
#   0.07853569 0.08218128 0.09286714 0.09170869]]

# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist

# Load dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Preprocess dataset
x_train = x_train.reshape(x_train.shape[0], 784) / 255.0
x_test = x_test.reshape(x_test.shape[0], 784) / 255.0


# Activation Functions

def relu(z):
    return np.maximum(0, z)


def softmax(z):

    exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))

    return exp_z / np.sum(exp_z, axis=1, keepdims=True)


# Neural Network Class

class FeedForwardNeuralNetwork:

    def __init__(self, input_size, hidden_layers, output_size):

        self.layers = [input_size] + hidden_layers + [output_size]

        self.weights = []
        self.biases = []

        # Initialize weights and biases

        for i in range(len(self.layers) - 1):

            weight = np.random.randn(
                self.layers[i],
                self.layers[i + 1]
            ) * np.sqrt(1 / self.layers[i])

            bias = np.zeros((1, self.layers[i + 1]))

            self.weights.append(weight)
            self.biases.append(bias)

    # FORWARD FUNCTION INSIDE CLASS
    def forward(self, X):

        activations = [X]

        A = X

        # Hidden layers

        for i in range(len(self.weights) - 1):

            Z = np.dot(A, self.weights[i]) + self.biases[i]

            A = relu(Z)

            activations.append(A)

        # Output layer

        Z = np.dot(A, self.weights[-1]) + self.biases[-1]

        output = softmax(Z)

        activations.append(output)

        return activations


# Create model

model = FeedForwardNeuralNetwork(
    input_size=784,
    hidden_layers=[128, 64],
    output_size=10
)

# Test forward pass

sample_input = x_train[:5]

outputs = model.forward(sample_input)

print(outputs[-1])

print("\nProbability sums:")
print(np.sum(outputs[-1], axis=1))
# Out:
# [[0.1248255  0.06123981 0.09527925 0.10074326 0.10123823 0.14660909
#   0.08677421 0.09527475 0.0868793  0.10113661]
#  [0.09830304 0.04693503 0.09628939 0.07836802 0.11511809 0.12292533
#   0.10390772 0.11072469 0.08659149 0.14083719]
#  [0.10359315 0.05959496 0.1051234  0.10332774 0.09857011 0.10150587
#   0.10533706 0.10058313 0.10403839 0.11832619]
#  [0.10362055 0.05182334 0.10420655 0.10017951 0.1005089  0.10799835
#   0.10897389 0.08872506 0.09641593 0.13754792]
#  [0.11000973 0.04833844 0.10020298 0.09086089 0.10171674 0.1272419
#   0.12158509 0.09770635 0.06772051 0.13461737]]
#
# Probability sums:
# [1. 1. 1. 1. 1.]

# %% [markdown]
# # Task 2: Feedforward Neural Network Implementation using NumPy
#
# ## Objective
# The objective of this task is to implement a fully connected feedforward neural network from scratch using NumPy for the Fashion-MNIST classification problem.
#
# The network takes Fashion-MNIST images as input and produces a probability distribution across 10 output classes using the Softmax activation function.
#
# ## Dataset
# The Fashion-MNIST dataset consists of grayscale images of clothing items belonging to 10 different categories.
#
# - Image size: 28 × 28 pixels
# - Total input features: 784
# - Training samples: 60,000
# - Testing samples: 10,000
# - Number of classes: 10
#
# ## Steps Performed
#
# ### 1. Data Loading
# The Fashion-MNIST dataset is loaded using:
# ```python
# from tensorflow.keras.datasets import fashion_mnist
